# %% [markdown]
# # Predicting Flight Rating
# The goal of this exercise is to use data on individual flights to predict whether or not a given flyer was satisfied with their experience. The target column will be the "Rating" column, whcih will be between 0 and 5

# %%
import pandas as pd
spark_df = spark.read.table("prod.interviews.airline_rating")
df = spark_df.toPandas()

# %% [markdown]
# ## EDA (60 Points)

# %% [markdown]
# ## ML Modeling (25 Points)

# %% [markdown]
# ## Reflection (15 Points)
