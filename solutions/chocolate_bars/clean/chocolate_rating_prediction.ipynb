# %% [markdown]
# # Predicting Chocolate Bar Ratings
# The goal of this exercise is to use data on chocolate bars produced to predict a 1-4 rating of the chocolate bar

# %%
import pandas as pd
spark_df = spark.read.table("main.interviews.chocolate_bar_ratings)
df = spark_df.toPandas()

# %% [markdown]
# ## EDA (60 Points)

# %% [markdown]
# ## ML Modeling (25 Points)

# %% [markdown]
# ## Reflection (15 Points)
